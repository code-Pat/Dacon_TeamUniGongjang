# %%
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import folium
from folium import plugins
from folium.features import CustomIcon
import json
import requests
import os
import webbrowser

# %%
seoul_data = pd.read_csv('C:/Big Data Contest/seoul_map_total.csv', header = 0)
#seoul_data = seoul_data.T
#seoul_data['Y2015-Y2014']
#column = ['Y2015-Y2014','Y2016-Y2015','Y2017-Y2016','Y2018-Y2017',
         # 'Y2019-Y2018','Y2020-Y2019','Y2021-Y2020','Y2021-Y2016', 'district_name']
#seoul_data = seoul_data.drop(['기간'])
#seoul_data.columns = column
#seoul_data = seoul_data[['Y2021-Y2016', 'district_name']]
#seoul_data['Y2021-Y2016'] = seoul_data['Y2021-Y2016'].astype(float)
#seoul_data['district_name'] = seoul_data['district_name'].astype(str)
#seoul_data.to_csv('./CSV/population/for_graph.csv')
#seoul_data.dtypes
#seoul_data.district_name = seoul_data.district_name.astype(str)
#seoul_data['Y2021-Y2016'] = seoul_data['Y2021-Y2016'].astype(float)

seoul_data_1 = seoul_data[['district_name', 'Y2021-Y2016']]
seoul_data_2 = seoul_data[['district_name', 'Y2021-Y2020']]
seoul_data_3 = seoul_data[['district_name', 'Y2020-Y2019']]
seoul_data_4 = seoul_data[['district_name', 'Y2019-Y2018']]
seoul_data_5 = seoul_data[['district_name', 'Y2018-Y2017']]
seoul_data_6 = seoul_data[['district_name', 'Y2017-Y2016']]

# %%
gyeongi_data = pd.read_csv('C:/Big Data Contest/gyeonggi_map_data1.csv', header = 0)
gyeongi_data.district_name = gyeongi_data.district_name.astype(str)
gyeongi_data['Y2021-Y2016'] = gyeongi_data['Y2021-Y2016'].astype(float)

# %%
req = requests.get('https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2013/json/skorea_municipalities_geo_simple.json')
state_geo = req.json()
#icon_image1 = './CSV/image/custom_circle.svg'

# %%
#print(state_geo)

# %%
seoul_map = folium.Map(location = [37.5502, 126.982],
                      zoom_start = 10.5)
                      #tiles = 'cartodbpositron')
                      #tiles = 'openstreetmap')
        
        


folium.Choropleth(
    geo_data = state_geo,
    name = '서울시 인구변화 16~21',
    data = seoul_data_1,
    columns = ['district_name','Y2021-Y2016'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)

folium.Choropleth(
    geo_data = state_geo,
    name = '서울시 인구변화 20~21',
    data = seoul_data_2,
    columns = ['district_name','Y2021-Y2020'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)

folium.Choropleth(
    geo_data = state_geo,
    name = '서울시 인구변화 19~20',
    data = seoul_data_3,
    columns = ['district_name','Y2020-Y2019'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)

folium.Choropleth(
    geo_data = state_geo,
    name = '서울시 인구변화 18~19',
    data = seoul_data_4,
    columns = ['district_name','Y2019-Y2018'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)

folium.Choropleth(
    geo_data = state_geo,
    name = '서울시 인구변화 17~18',
    data = seoul_data_5,
    columns = ['district_name','Y2018-Y2017'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)

folium.Choropleth(
    geo_data = state_geo,
    name = '서울시 인구변화 16~17',
    data = seoul_data_6,
    columns = ['district_name','Y2017-Y2016'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)


folium.Choropleth(
    geo_data = state_geo,
    name = '경기도 시각화',
    data = gyeongi_data,
    columns = ['district_name', 'Y2021-Y2016'],
    key_on = 'feature.properties.name',
    fill_color = 'Greens',
    fill_opacity = 0.7,
    line_opacity = 0.3,
    color = 'gray',
    legend_name = 'growth rate'
    ).add_to(seoul_map)

fg = folium.FeatureGroup(name = 'markers')
seoul_map.add_child(fg)
g1 = folium.plugins.FeatureGroupSubGroup(fg, 'B_Points')
seoul_map.add_child(g1)
g2 = folium.plugins.FeatureGroupSubGroup(fg, 'C_Points')
seoul_map.add_child(g2)
g3 = folium.plugins.FeatureGroupSubGroup(fg, 'D_Points')
seoul_map.add_child(g3)
g4 = folium.plugins.FeatureGroupSubGroup(fg, 'F_Points')
seoul_map.add_child(g4)

Ifg = folium.FeatureGroup(name = 'Inflow_markers')
seoul_map.add_child(Ifg)
g5 = folium.plugins.FeatureGroupSubGroup(Ifg, 'Circle_Inflow_B')
seoul_map.add_child(g5)
g6 = folium.plugins.FeatureGroupSubGroup(Ifg, 'Circle_Inflow_C')
seoul_map.add_child(g6)
g7 = folium.plugins.FeatureGroupSubGroup(Ifg, 'Circle_Inflow_D')
seoul_map.add_child(g7)
g8 = folium.plugins.FeatureGroupSubGroup(Ifg, 'Circle_Inflow_F')
seoul_map.add_child(g8)

Sfg = folium.FeatureGroup(name = 'Spill_markers')
seoul_map.add_child(Sfg)
g9 = folium.plugins.FeatureGroupSubGroup(Sfg, 'Circle_Spill_B')
seoul_map.add_child(g9)
g10 = folium.plugins.FeatureGroupSubGroup(Sfg, 'Circle_Spill_C')
seoul_map.add_child(g10)
g11 = folium.plugins.FeatureGroupSubGroup(Sfg, 'Circle_Spill_D')
seoul_map.add_child(g11)
g12 = folium.plugins.FeatureGroupSubGroup(Sfg, 'Circle_Spill_F')
seoul_map.add_child(g12)

folium.LayerControl(collapsed = True).add_to(seoul_map)

# %%
icon_number_b1 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 1,
    inner_icon_style = 'margin-top:0'
)
icon_number_b2 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 2,
    inner_icon_style = 'margin-top:0'
)
icon_number_b3 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 3,
    inner_icon_style = 'margin-top:0'
)
icon_number_b4 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_b5 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_b6 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_b7 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_b8 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_b9 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 9,
    inner_icon_style = 'margin-top:0'
)
icon_number_b10 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 10,
    inner_icon_style = 'margin-top:0'
)
icon_number_b11 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 11,
    inner_icon_style = 'margin-top:0'
)
icon_number_b12 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 12,
    inner_icon_style = 'margin-top:0'
)
icon_number_b13 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 13,
    inner_icon_style = 'margin-top:0'
)
icon_number_b14 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 14,
    inner_icon_style = 'margin-top:0'
)
icon_number_b15 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 15,
    inner_icon_style = 'margin-top:0'
)
icon_number_b16 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 16,
    inner_icon_style = 'margin-top:0'
)
icon_number_b17 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 17,
    inner_icon_style = 'margin-top:0'
)
icon_number_b18 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 18,
    inner_icon_style = 'margin-top:0'
)
icon_number_b19 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 19,
    inner_icon_style = 'margin-top:0'
)
icon_number_b20 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 20,
    inner_icon_style = 'margin-top:0'
)
icon_number_b21 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 21,
    inner_icon_style = 'margin-top:0'
)
icon_number_b22 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 22,
    inner_icon_style = 'margin-top:0'
)
icon_number_b23 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 23,
    inner_icon_style = 'margin-top:0'
)
icon_number_b24 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 24,
    inner_icon_style = 'margin-top:0'
)
icon_number_b25 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 25,
    inner_icon_style = 'margin-top:0'
)
icon_number_b26 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 26,
    inner_icon_style = 'margin-top:0'
)
icon_number_b27 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 27,
    inner_icon_style = 'margin-top:0'
)
icon_number_b28 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 28,
    inner_icon_style = 'margin-top:0'
)
icon_number_b29 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 29,
    inner_icon_style = 'margin-top:0'
)
icon_number_b30 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 30,
    inner_icon_style = 'margin-top:0'
)
icon_number_b31 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 31,
    inner_icon_style = 'margin-top:0'
)
icon_number_b32 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 32,
    inner_icon_style = 'margin-top:0'
)
icon_number_b33 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 33,
    inner_icon_style = 'margin-top:0'
)
icon_number_b34 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 34,
    inner_icon_style = 'margin-top:0'
)
icon_number_b35 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 35,
    inner_icon_style = 'margin-top:0'
)
icon_number_b36 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 36,
    inner_icon_style = 'margin-top:0'
)
icon_number_b37 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 37,
    inner_icon_style = 'margin-top:0'
)


tooltip = "Click"

# %%
folium.Marker(
    location = [37.6899062,127.0428593], 
    popup = folium.Popup("<b>B-1 도봉로 <br>유입:12.00% <br>유출:-8.30% </br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b1
    ).add_to(g1)

folium.Marker(
    location = [37.6941317,127.0509975],
    popup = folium.Popup("<b>B-2 동일로 <br>유입:-46.43% <br>유출:-4.21%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b2
    ).add_to(g1)

folium.Marker(
    location = [37.5544386,127.1083746],
    popup = folium.Popup("<b>B-3 아차산로 <br>유입:38.11% <br>유출:14.49%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b3
    ).add_to(g1)

folium.Marker(
    location = [37.5947282,127.1102168],
    popup = folium.Popup("<b>B-4 망우로 <br>유입:-13.10% <br>유출:-14.88%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b4
).add_to(g1)

folium.Marker(
    location = [37.6186095,127.1023901],
    popup = folium.Popup("<b>B-5 경춘북로 <br>유입:-0.37% <br>유출:28.67%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b5
).add_to(g1)

folium.Marker(
    location = [37.6186082,127.0871067],
    popup = folium.Popup("<b>B-6 화랑로 <br>유입:-25.11% <br>유출:-15.93%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b6
).add_to(g1)

folium.Marker(
    location = [37.6111681,127.1124202],
    popup = folium.Popup("<b>B-7 북부간선 <br>유입:7.43% <br>유출:15.09%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b7
).add_to(g1)

folium.Marker(
    location = [37.5126834,127.1500208],
    popup = folium.Popup("<b>B-8 서하남로 <br>유입:-4.44% <br>유출:-1.39%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b8
).add_to(g1)

folium.Marker(
    location = [37.5491794,127.177156],
    popup = folium.Popup("<b>B-9 천호대로 <br>유입:1.86% <br>유출:-0.24%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b9
).add_to(g1)

folium.Marker(
    location = [37.5730652,127.1634344], 
    popup = folium.Popup("<b>B-10 올림픽대로 <br>유입:10.72% <br>유출:18.13%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b10
).add_to(g1)

folium.Marker(
    location = [37.4634929,127.0375331],
    popup = folium.Popup("<b>B-11 경부고속 <br>유입:-7.98% <br>유출:-21.89%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b11
).add_to(g1)

folium.Marker(
    location = [37.4701094,127.1217181],
    popup = folium.Popup("<b>B-12 송파대로 <br>유입:-% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b12
).add_to(g1)

folium.Marker(
    location = [37.4647718,127.106082],
    popup = folium.Popup("<b>B-13 밤고개로 <br>유입:-% <br>유출:-%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b13
).add_to(g1)

folium.Marker(
    location = [37.3718672,127.0997269],
    popup = folium.Popup("<b>B-14 분당수서 <br>유입:1.32% <br>유출:0.15%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b14
).add_to(g1)

folium.Marker(
    location = [37.464237,126.9869137],
    popup = folium.Popup("<b>B-15 과천대로 <br>유입:-20.66% <br>유출:-19.59%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b15
).add_to(g1)

folium.Marker(
    location = [37.4634929,127.0375331],
    popup = folium.Popup("<b>B-16 양재대로 <br>유입:-% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b16
).add_to(g1)

folium.Marker(
    location = [37.4698955,127.0111568],
    popup = folium.Popup("<b>B-17 반포대로 <br>유입:96.29% <br>유출:145.83%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b17
).add_to(g1)

folium.Marker(
    location = [37.435161,126.9000497], 
    popup = folium.Popup("<b>B-18 시흥대로 <br>유입:-5.02% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b18
).add_to(g1)

folium.Marker(
    location = [37.4369705,126.8144138],
    popup = folium.Popup("<b>B-19 금오로 <br>유입:4.70% <br>유출:0.00%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b19
).add_to(g1)

folium.Marker(
    location = [37.4468478,126.8315392], 
    popup = folium.Popup("<b>B-20 오리로 <br>유입:-12.89% <br>유출:8.58%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b20
).add_to(g1)

folium.Marker(
    location = [37.4856259,126.8543174], 
    popup = folium.Popup("<b>B-21 개봉로 <br>유입:-0.18% <br>유출:-6.05%</br></br></b>",  max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b21
).add_to(g1)

folium.Marker(
    location = [37.4849595,126.8688716],
    popup = folium.Popup("<b>B-22 광명대교 <br>유입:4.75% <br>유출:-9.68%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b22
).add_to(g1)

folium.Marker(
    location = [37.4811723,126.8598571],
    popup = folium.Popup("<b>B-23 철산교 <br>유입:-7.41% <br>유출:-10.14%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b23
).add_to(g1)

folium.Marker(
    location = [37.4659066,126.8853011], 
    popup = folium.Popup("<b>B-24 금천교 <br>유입:-% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b24
).add_to(g1)

folium.Marker(
    location = [37.4516714,126.8997134], 
    popup = folium.Popup("<b>B-25 금하로 <br>유입:-5.06% <br>유출:-30.56%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b25
).add_to(g1)

folium.Marker(
    location = [37.5192016,126.754606], 
    popup = folium.Popup("<b>B-26 오정로 <br>유입:-41.17% <br>유출:-30.93%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b26
).add_to(g1)

folium.Marker(
    location = [37.5393132,126.8237634],
    popup = folium.Popup("<b>B-27 화곡로 <br>유입:-12.46% <br>유출:-12.66%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b27
).add_to(g1)

folium.Marker(
    location = [37.5255095,126.8331795], 
    popup = folium.Popup("<b>B-28 경인고속국도 <br>유입:-0.34% <br>유출:-3.93%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b28
).add_to(g1)

folium.Marker(
    location = [37.4879732,126.8217219], 
    popup = folium.Popup("<b>B-29 경인로 <br>유입:-10.31% <br>유출:-8.58%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b29
).add_to(g1)

folium.Marker(
    location = [37.506039,126.820681], 
    popup = folium.Popup("<b>B-30 신정로 <br>유입:-% <br>유출:-%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b30
).add_to(g1)

folium.Marker(
    location = [37.491799,126.7487928], 
    popup = folium.Popup("<b>B-31 김포대로 <br>유입:-4.63% <br>유출:-10.51%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b31
).add_to(g1)

folium.Marker(
    location = [37.5842516,126.7950705], 
    popup = folium.Popup("<b>B-32 올림픽대로 <br>유입:83.99% <br>유출:92.59%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b32
).add_to(g1)

folium.Marker(
    location = [37.6218508,126.906438], 
    popup = folium.Popup("<b>B-33 통일로 <br>유입:-0.03% <br>유출:-0.11%</br></br></b>",  max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b33
).add_to(g1)

folium.Marker(
    location = [37.6331794,126.8432692], 
    popup = folium.Popup("<b>B-34 서오릉로 <br>유입:-14.94% <br>유출:-14.40%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b34
).add_to(g1)

folium.Marker(
    location = [37.5722784,126.9011233],
    popup = folium.Popup("<b>B-35 수색로 <br>유입:-3.98% <br>유출:-10.20%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b35
).add_to(g1)

folium.Marker(
    location = [37.569246,126.8687315], 
    popup = folium.Popup("<b>B-36 강변북로(난지공원) <br>유입:0.05% <br>유출:-7.09%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b36
).add_to(g1)

folium.Marker(
    location = [37.5756393,127.1227722], 
    popup = folium.Popup("<b>B-37 강변북로(구리시계) <br>유입:-% <br>유출:-%</br></br></b>",  max_width = 200),
    tooltip = tooltip,
    icon = icon_number_b37
).add_to(g1)

# %%
icon_number_c1 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 1,
    inner_icon_style = 'margin-top:0'
)
icon_number_c3 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 3,
    inner_icon_style = 'margin-top:0'
)
icon_number_c4 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_c5 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_c6 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_c7 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_c8 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_c9 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 9,
    inner_icon_style = 'margin-top:0'
)
icon_number_c10 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 10,
    inner_icon_style = 'margin-top:0'
)
icon_number_c11 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 11,
    inner_icon_style = 'margin-top:0'
)
icon_number_c12 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 12,
    inner_icon_style = 'margin-top:0'
)
icon_number_c13 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 13,
    inner_icon_style = 'margin-top:0'
)
icon_number_c14 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 14,
    inner_icon_style = 'margin-top:0'
)
icon_number_c15 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 15,
    inner_icon_style = 'margin-top:0'
)
icon_number_c16 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 16,
    inner_icon_style = 'margin-top:0'
)
icon_number_c17 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 17,
    inner_icon_style = 'margin-top:0'
)
icon_number_c18 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 18,
    inner_icon_style = 'margin-top:0'
)
icon_number_c19 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 19,
    inner_icon_style = 'margin-top:0'
)
icon_number_c20 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 20,
    inner_icon_style = 'margin-top:0'
)
icon_number_c21 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 21,
    inner_icon_style = 'margin-top:0'
)

# %%
folium.Marker(
    location = [37.5980835,126.8076522], 
    popup = folium.Popup("<b>C-01 행주대교 <br>유입:8.99% <br>유출:1.37%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c1
).add_to(g2)

folium.Marker(
    location = [37.5692971,126.8588536], 
    popup = folium.Popup("<b>C-03 가양대로 <br>유입:5.64% <br>유출:-3.90%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c3
).add_to(g2)

folium.Marker(
    location = [37.5528405,126.889451], 
    popup = folium.Popup("<b>C-04 성산대교 <br>유입:0.02% <br>유출:-2.16%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c4
).add_to(g2)

folium.Marker(
    location = [37.541873,126.9004095], 
    popup = folium.Popup("<b>C-05 양화대교 <br>유입:5.84% <br>유출:4.24%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c5
).add_to(g2)

folium.Marker(
    location = [37.5370177,126.9228495], 
    popup = folium.Popup("<b>C-06 서강대교 <br>유입:-23.05% <br>유출:-7.50%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c6
).add_to(g2)

folium.Marker(
    location = [37.5337975,126.9349198], 
    popup = folium.Popup("<b>C-07 마포대교 <br>유입:-11.61% <br>유출:10.03%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c7
).add_to(g2)

folium.Marker(
    location = [37.527039,126.94353], 
    popup = folium.Popup("<b>C-08 원효대교 <br>유입:-7.99% <br>유출:-5.42%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c8
).add_to(g2)

folium.Marker(
    location = [37.5175177,126.9566667], 
    popup = folium.Popup("<b>C-09 한강대교 <br>유입:-7.87% <br>유출:-9.11%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c9
).add_to(g2)

folium.Marker(
    location = [37.5086737,126.9792945], 
    popup = folium.Popup("<b>C-10 동작대교 <br>유입:-4.65% <br>유출:2.67%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c10
).add_to(g2)

folium.Marker(
    location = [37.5141186,126.9959445], 
    popup = folium.Popup("<b>C-11 반포대교 <br>유입:0.79% <br>유출:-14.27%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c11
).add_to(g2)

folium.Marker(
    location = [37.5146526,126.9953166], 
    popup = folium.Popup("<b>C-12 잠수교 <br>유입:29.33% <br>유출:-55.46%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c12
).add_to(g2)

folium.Marker(
    location = [37.5258295,127.0133125], 
    popup = folium.Popup("<b>C-13 한남대교 <br>유입:-0.52% <br>유출:-4.04%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c13
).add_to(g2)

folium.Marker(
    location = [37.536178,127.018856], 
    popup = folium.Popup("<b>C-14 동호대교 <br>유입:-2.45% <br>유출:-1.80%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c14
).add_to(g2)

folium.Marker(
    location = [37.5370472,127.0327411], 
    popup = folium.Popup("<b>C-15 성수대교 <br>유입:2.33% <br>유출:-5.35%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c15
).add_to(g2)

folium.Marker(
    location = [37.530207,127.055019], 
    popup = folium.Popup("<b>C-16 영동대교 <br>유입:-2.88% <br>유출:-0.76%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c16
).add_to(g2)

folium.Marker(
    location = [37.526569,127.062268], 
    popup = folium.Popup("<b>C-17 청담대교 <br>유입:1.52% <br>유출:-0.30%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c17
).add_to(g2)

folium.Marker(
    location = [37.5243505,127.0894026], 
    popup = folium.Popup("<b>C-18 잠실대교 <br>유입:-6.78% <br>유출:1.45%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c18
).add_to(g2)

folium.Marker(
    location = [37.5339577,127.1016808], 
    popup = folium.Popup("<b>C-19 올림픽대교 <br>유입:-2.13% <br>유출:2.03%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c19
).add_to(g2)

folium.Marker(
    location = [37.542929,127.1095965], 
    popup = folium.Popup("<b>C-20 천호대교 <br>유입:-11.95% <br>유출:-1.96%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c20
).add_to(g2)

folium.Marker(
    location = [37.544881,127.110604], 
    popup = folium.Popup("<b>C-21 광진교 <br>유입:-22.70% <br>유출:-37.03%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_c21
).add_to(g2)

# %%
icon_number_d1 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 1 ,
    inner_icon_style = 'margin-top:0'
)
icon_number_d2 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 2,
    inner_icon_style = 'margin-top:0'
)
icon_number_d3 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 3,
    inner_icon_style = 'margin-top:0'
)
icon_number_d4 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_d5 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_d6 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_d7 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_d8 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_d9 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 9,
    inner_icon_style = 'margin-top:0'
)
icon_number_d10 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 10,
    inner_icon_style = 'margin-top:0'
)
icon_number_d11 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 11,
    inner_icon_style = 'margin-top:0'
)
icon_number_d12 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 12,
    inner_icon_style = 'margin-top:0'
)
icon_number_d13 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 13,
    inner_icon_style = 'margin-top:0'
)
icon_number_d14 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 14,
    inner_icon_style = 'margin-top:0'
)
icon_number_d15 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 15,
    inner_icon_style = 'margin-top:0'
)
icon_number_d16 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 16,
    inner_icon_style = 'margin-top:0'
)
icon_number_d17 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 17,
    inner_icon_style = 'margin-top:0'
)
icon_number_d18 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 18,
    inner_icon_style = 'margin-top:0'
)
icon_number_d19 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 19,
    inner_icon_style = 'margin-top:0'
)
icon_number_d20 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 20,
    inner_icon_style = 'margin-top:0'
)
icon_number_d21 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 21,
    inner_icon_style = 'margin-top:0'
)
icon_number_d22 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 22,
    inner_icon_style = 'margin-top:0'
)
icon_number_d23 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 23,
    inner_icon_style = 'margin-top:0'
)
icon_number_d24 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 24,
    inner_icon_style = 'margin-top:0'
)
icon_number_d25 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 25,
    inner_icon_style = 'margin-top:0'
)
icon_number_d26 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 26,
    inner_icon_style = 'margin-top:0'
)
icon_number_d27 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 27,
    inner_icon_style = 'margin-top:0'
)
icon_number_d28 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 28,
    inner_icon_style = 'margin-top:0'
)
icon_number_d29 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 29,
    inner_icon_style = 'margin-top:0'
)
icon_number_d30 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 30,
    inner_icon_style = 'margin-top:0'
)
icon_number_d31 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 31,
    inner_icon_style = 'margin-top:0'
)
icon_number_d32 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 32,
    inner_icon_style = 'margin-top:0'
)
icon_number_d33 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 33,
    inner_icon_style = 'margin-top:0'
)
icon_number_d34 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 34,
    inner_icon_style = 'margin-top:0'
)
icon_number_d35 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 35,
    inner_icon_style = 'margin-top:0'
)
icon_number_d36 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 36,
    inner_icon_style = 'margin-top:0'
)
icon_number_d37 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 37,
    inner_icon_style = 'margin-top:0'
)
icon_number_d38 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 38,
    inner_icon_style = 'margin-top:0'
)
icon_number_d39 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 39,
    inner_icon_style = 'margin-top:0'
)
icon_number_d40 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 40,
    inner_icon_style = 'margin-top:0'
)
icon_number_d41 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 41,
    inner_icon_style = 'margin-top:0'
)
icon_number_d42 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 42,
    inner_icon_style = 'margin-top:0'
)
icon_number_d43 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 43,
    inner_icon_style = 'margin-top:0'
)
icon_number_d44 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 44,
    inner_icon_style = 'margin-top:0'
)
icon_number_d45 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 45,
    inner_icon_style = 'margin-top:0'
)

# %%
folium.Marker(
    location = [37.6094457,126.9490825], 
    popup = folium.Popup("<b>D-01 진흥로 <br>유입:3.71% <br>유출:-0.59%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d1
).add_to(g3)

folium.Marker(
    location = [37.611668,126.982551], 
    popup = folium.Popup("<b>D-02 평창문화로 <br>유입:6.75% <br>유출:50.74%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d2
).add_to(g3)

folium.Marker(
    location = [37.5504819,127.0119391], 
    popup = folium.Popup("<b>D-03 동호로 <br>유입:-10.64% <br>유출:-8.48%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d3
).add_to(g3)

folium.Marker(
    location = [37.529361,127.00679], 
    popup = folium.Popup("<b>D-04 서빙고로 <br>유입:0.54% <br>유출:-0.44%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d4
).add_to(g3)

folium.Marker(
    location = [37.5610318,127.0714966], 
    popup = folium.Popup("<b>D-05 천호대로 <br>유입:-4.35% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d5
).add_to(g3)

folium.Marker(
    location = [37.5455896,127.0291416], 
    popup = folium.Popup("<b>D-06 뚝섬로 <br>유입:2.04% <br>유출:-3.86%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d6
).add_to(g3)

folium.Marker(
    location = [37.5559148,127.0707977], 
    popup = folium.Popup("<b>D-07 동일로 <br>유입:-15.59% <br>유출:-0.62%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d7
).add_to(g3)

folium.Marker(
    location = [37.606604,127.046677], 
    popup = folium.Popup("<b>D-08 화랑로 <br>유입:-5.35% <br>유출:47.83%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d8
).add_to(g3)

folium.Marker(
    location = [37.6015956,127.0189499], 
    popup = folium.Popup("<b>D-09 동소문로 <br>유입:-4.41% <br>유출:-6.60%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d9
).add_to(g3)

folium.Marker(
    location = [37.6015747,126.9533875], 
    popup = folium.Popup("<b>D-10 화랑로 <br>유입:-12.85% <br>유출:-11.30%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d10
).add_to(g3)

folium.Marker(
    location = [37.6435347,127.0240008], 
    popup = folium.Popup("<b>D-11 도봉로 <br>유입:-8.99% <br>유출:-7.14%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d11
).add_to(g3)

folium.Marker(
    location = [37.6327227,127.060932], 
    popup = folium.Popup("<b>D-12 동부간선도로 <br>유입:-6.39% <br>유출:-0.72%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d12
).add_to(g3)

folium.Marker(
    location = [37.655341,127.0596715], 
    popup = folium.Popup("<b>D-13 동일로 <br>유입:-% <br>유출:-9.74%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d13
).add_to(g3)

folium.Marker(
    location = [37.5779636,126.8982265], 
    popup = folium.Popup("<b>D-14 증산로 <br>유입:-8.91% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d14
).add_to(g3)

folium.Marker(
    location = [37.59501,126.938436], 
    popup = folium.Popup("<b>D-15 통일로 <br>유입:-3.45% <br>유출:-2.60%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d15
).add_to(g3)

folium.Marker(
    location = [37.5644231,126.9268637], 
    popup = folium.Popup("<b>D-16 성산로 <br>유입:-8.72% <br>유출:-2.49%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d16
).add_to(g3)

folium.Marker(
    location = [37.5644094,126.9269758], 
    popup = folium.Popup("<b>D-17 연희로 <br>유입:0.33% <br>유출:-18.27%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d17
).add_to(g3)

folium.Marker(
    location = [37.5393132,126.8237634], 
    popup = folium.Popup("<b>D-18 남부순환로 <br>유입:-17.95% <br>유출:-9.35%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d18
).add_to(g3)

folium.Marker(
    location = [37.5255095,126.8331795], 
    popup = folium.Popup("<b>D-19 남부순환로 <br>유입:25.26% <br>유출:14.85%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d19
).add_to(g3)

folium.Marker(
    location = [37.5360361,126.8418728], 
    popup = folium.Popup("<b>D-20 강서로 <br>유입:-7.19% <br>유출:-7.87%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d20
).add_to(g3)

folium.Marker(
    location = [37.558683,126.835401], 
    popup = folium.Popup("<b>D-21 공항대로 <br>유입:-% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d21
).add_to(g3)

folium.Marker(
    location = [37.4980687,126.8465123], 
    popup = folium.Popup("<b>D-22 경인로 <br>유입:-8.95% <br>유출:-8.07%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d22
).add_to(g3)

folium.Marker(
    location = [37.5069016,126.8831751], 
    popup = folium.Popup("<b>D-23 경인로 <br>유입:-4.90% <br>유출:-7.59%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d23
).add_to(g3)

folium.Marker(
    location = [37.4558229,126.794963], 
    popup = folium.Popup("<b>D-24 시흥대로 <br>유입:-% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d24
).add_to(g3)

folium.Marker(
    location = [37.524553,126.872856], 
    popup = folium.Popup("<b>D-25 영등포로 <br>유입:-8.64% <br>유출:-6.66%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d25
).add_to(g3)

folium.Marker(
    location = [37.485215,126.8994], 
    popup = folium.Popup("<b>D-26 시흥대로 <br>유입:-% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d26
).add_to(g3)

folium.Marker(
    location = [37.5262608,126.9100609], 
    popup = folium.Popup("<b>D-27 국회대로 <br>유입:-32.83% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d27
).add_to(g3)

folium.Marker(
    location = [37.52065,126.913755], 
    popup = folium.Popup("<b>D-28 경인로 <br>유입:-22.63% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d28
).add_to(g3)

folium.Marker(
    location = [37.4926529,126.9127281], 
    popup = folium.Popup("<b>D-29 여의대방로 <br>유입:-3.51% <br>유출:-8.35%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d29
).add_to(g3)

folium.Marker(
    location = [37.5086836,126.949916], 
    popup = folium.Popup("<b>D-30 양녕로 <br>유입:5.45% <br>유출:4.83%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d30
).add_to(g3)

folium.Marker(
    location = [37.4869898,126.9798559], 
    popup = folium.Popup("<b>D-31 동작대로 <br>유입:1.36% <br>유출:-19.76%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d31
).add_to(g3)

folium.Marker(
    location = [37.4784043,126.9181706], 
    popup = folium.Popup("<b>D-32 문성로 <br>유입:2.21% <br>유출:-11.65%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d32
).add_to(g3)

folium.Marker(
    location = [37.477117,126.961224], 
    popup = folium.Popup("<b>D-33 남부순환로 <br>유입:-1.51% <br>유출:-2.41%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d33
).add_to(g3)

folium.Marker(
    location = [37.4789459,127.0092195], 
    popup = folium.Popup("<b>D-34 남부순환로 <br>유입:-6.50% <br>유출:-3.94%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d34
).add_to(g3)

folium.Marker(
    location = [37.4979083,127.0200692], 
    popup = folium.Popup("<b>D-35 강남대로 <br>유입:-6.65% <br>유출:-14.51%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d35
).add_to(g3)

folium.Marker(
    location = [37.504522,127.0017981], 
    popup = folium.Popup("<b>D-36 사평대로 <br>유입:-10.88% <br>유출:-10.84%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d36
).add_to(g3)

folium.Marker(
    location = [37.49184,127.005494], 
    popup = folium.Popup("<b>D-37 반포대로 <br>유입:-16.67% <br>유출:-12.54%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d37
).add_to(g3)

folium.Marker(
    location = [37.490712,127.0462986], 
    popup = folium.Popup("<b>D-38 언주로 <br>유입:-7.93% <br>유출:-6.71%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d38
).add_to(g3)

folium.Marker(
    location = [37.4874685,127.0991305], 
    popup = folium.Popup("<b>D-39 남부순환로 <br>유입:35.28% <br>유출:5.20%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d39
).add_to(g3)

folium.Marker(
    location = [37.4647718,127.1060713], 
    popup = folium.Popup("<b>D-40 헌릉로 <br>유입:-7.31% <br>유출:-4.58%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d40
).add_to(g3)

folium.Marker(
    location = [37.5153466,126.9300843], 
    popup = folium.Popup("<b>D-41 노들로 <br>유입:24.86% <br>유출:17.98%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d41
).add_to(g3)

folium.Marker(
    location = [37.5051365,127.046395], 
    popup = folium.Popup("<b>D-42 테헤란로 <br>유입:-8.51% <br>유출:-11.51%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d42
).add_to(g3)

folium.Marker(
    location = [37.5237561,127.0112143], 
    popup = folium.Popup("<b>D-43 강남대로 <br>유입:-32.92% <br>유출:-29.81%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d43
).add_to(g3)

folium.Marker(
    location = [37.5237506,126.9848424], 
    popup = folium.Popup("<b>D-44 백제고분로 <br>유입:-33.69% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d44
).add_to(g3)

folium.Marker(
    location = [37.499739,127.110007], 
    popup = folium.Popup("<b>D-45 송파대로 <br>유입:9.65% <br>유출:-%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_d45
).add_to(g3)

# %%
icon_number_f1 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 1,
    inner_icon_style = 'margin-top:0'
)
icon_number_f2 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 2,
    inner_icon_style = 'margin-top:0'
)
icon_number_f3_1 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 3.1,
    inner_icon_style = 'margin-top:0'
)
icon_number_f3_2 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 3.2,
    inner_icon_style = 'margin-top:0'
)
icon_number_f4 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_f5 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_f6 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_f7 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_f8 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_f9 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 9,
    inner_icon_style = 'margin-top:0'
)

# %%
folium.Marker(
    location = [37.5051387,126.9647395], 
    popup = folium.Popup("<b>F-01 올림픽대로 <br>유입:-1.68% <br>유출:-4.34%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f1
).add_to(g4)

folium.Marker(
    location = [37.511198,126.967319], 
    popup = folium.Popup("<b>F-02 강변북로 <br>유입:-10.72% <br>유출:1.50%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f2
).add_to(g4)

folium.Marker(
    location = [37.5947411,126.9541272], 
    popup = folium.Popup("<b>F-03 내부순환로(유출) <br>유입:-4.27% <br>유출:-6.63%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f3_1
).add_to(g4)

folium.Marker(
    location = [37.6076494,126.9928635], 
    popup = folium.Popup("<b>F-03 내부순환로(유입) <br>유입:-4.27% <br>유출:-6.63%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f3_2
).add_to(g4)

folium.Marker(
    location = [37.6044901,127.0526307], 
    popup = folium.Popup("<b>F-04 북부간선도로 <br>유입:-1.01% <br>유출:5.92%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f4
).add_to(g4)

folium.Marker(
    location = [37.574336, 127.077292], 
    popup = folium.Popup("<b>F-05 동부간선도로 <br>유입:-6.87% <br>유출:-3.11%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f5
).add_to(g4)

folium.Marker(
    location = [37.493237, 127.022355], 
    popup = folium.Popup("<b>F-06 경부고속도로 <br>유입:-2.23% <br>유출:-2.62%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f6
).add_to(g4)

folium.Marker(
    location = [37.497939, 127.085948], 
    popup = folium.Popup("<b>F-07 분당수서로 <br>유입:-1.51% <br>유출:-17.44%</br></br></b>",max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f7
).add_to(g4)

folium.Marker(
    location = [37.446118, 126.923663], 
    popup = folium.Popup("<b>F-08 강남순환로 <br>유입:25.60% <br>유출:8.40%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f8
).add_to(g4)

folium.Marker(
    location = [37.521245, 126.881726], 
    popup = folium.Popup("<b>F-09 서부간선도로 <br>유입:-17.20% <br>유출:-24.73%</br></br></b>", max_width = 200),
    tooltip = tooltip,
    icon = icon_number_f9
).add_to(g4)

# %%
# B지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.4698955,127.0111568],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g5)

folium.CircleMarker(
    [37.5842516,126.7950705],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g5)

folium.CircleMarker(
    [37.5544386,127.1083746],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g5)

# C지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.5146526,126.9953166],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g6)

folium.CircleMarker(
    [37.5980835,126.8076522],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g6)

folium.CircleMarker(
    [37.541873,126.9004095],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g6)

# D지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.4874685,127.0991305],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.5255095,126.8331795],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.5153466,126.9300843],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.499739,127.110007],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.611668,126.982551],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

# F지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.446118, 126.923663],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g8)

# %%
# B지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.4698955,127.0111568],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g9)

folium.CircleMarker(
    [37.5842516,126.7950705],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g9)

folium.CircleMarker(
    [37.6186095,127.1023901],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g9)

# C지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.5146526,126.9953166],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g10)

folium.CircleMarker(
    [37.5337975,126.9349198],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g10)

folium.CircleMarker(
    [37.541873,126.9004095],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g10)

# D지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.611668,126.982551],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.606604,127.046677],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.5153466,126.9300843],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.5255095,126.8331795],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.4874685,127.0991305],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

# F지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.446118, 126.923663],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g12)

folium.CircleMarker(
    [37.6044901,127.0526307],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g12)

folium.CircleMarker(
    [37.511198,126.967319],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g12)

# %%
seoul_map.save('C:/Big Data Contest/sudogwon_map16_18.html')
