# %%
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import folium
from folium import plugins
from folium.features import CustomIcon
import json
import requests
import os
import webbrowser

# %%
seoul_data = pd.read_csv('./CSV/population/seoul_map_total.csv', header = 0)
seoul_data_1 = seoul_data[['district_name', 'Y2018-Y2016']]
seoul_data_2 = seoul_data[['district_name', 'Y2021-Y2018']]

gyeonggi_data = pd.read_csv('./CSV/population/gyeonggi_data_total.csv', header = 0)
gyeonggi_data_1 = gyeonggi_data[['District_Name', 'Y2018-Y2016']]
gyeonggi_data_2 = gyeonggi_data[['District_Name', 'Y2021-Y2018']]

# %%
req = requests.get('https://raw.githubusercontent.com/southkorea/southkorea-maps/master/kostat/2013/json/skorea_municipalities_geo_simple.json')
state_geo = req.json()

# %%
m = folium.plugins.DualMap(location = [37.5502, 126.982], 
                           zoom_start = 10.5,
                          tiles = 'openstreetmap')

layer_1 = folium.features.Choropleth( 
    geo_data = state_geo,
    name = '서울시 인구 증감율 16~18',
    data = seoul_data_1,
    columns = ['district_name', 'Y2018-Y2016'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.8,
    line_opacity = 0.5,
    color = 'gray',
    legend_name = '서울 16-18'
).add_to(m.m1)

layer_2 = folium.features.Choropleth( 
    geo_data = state_geo,
    name = '서울시 인구 증감율 18~21',
    data = seoul_data_2,
    columns = ['district_name', 'Y2021-Y2018'],
    key_on = 'feature.properties.name',
    fill_color = 'Blues',
    fill_opacity = 0.8,
    line_opacity = 0.5,
    color = 'gray',
    legend_name = '서울 18-21'
).add_to(m.m2)

layer_3 = folium.features.Choropleth(
    geo_data = state_geo,
    name = '경기도 인구 증감율 16~18',
    data = gyeonggi_data_1,
    columns = ['District_Name', 'Y2018-Y2016'],
    key_on = 'feature.properties.name',
    fill_color = 'Greens',
    fill_opacity = 0.8,
    line_opacity = 0.5,
    color = 'gray',
    legend_name = '경기 16-18'
).add_to(m.m1)

layer_4 = folium.features.Choropleth(
    geo_data = state_geo,
    name = '경기도 인구 증감율 18~21',
    data = gyeonggi_data_2,
    columns = ['District_Name', 'Y2021-Y2018'],
    key_on = 'feature.properties.name',
    fill_color = 'Greens',
    fill_opacity = 0.8,
    line_opacity = 0.5,
    color = 'gray',
    legend_name = '경기 18-21'
).add_to(m.m2)

#fg_1 = folium.FeatureGroup(name = '서울시 시각화 2016~2018').add_to(m.m1)
#fg_2 = folium.FeatureGroup(name = '서울시 시각화 2018~2021').add_to(m.m2)
#fg_3 = folium.FeatureGroup(name = '경기도 시각화 2016~2018').add_to(m.m1)
#fg_4 = folium.FeatureGroup(name = '경기도 시각화 2018~2021').add_to(m.m2)

#layer_1.geojson.add_to(fg_1)
#layer_2.geojson.add_to(fg_2)
#layer_3.geojson.add_to(fg_1)
#layer_4.geojson.add_to(fg_2)

#fg_1.add_to(m.m1)
#fg_2.add_to(m.m2)
#fg_3.add_to(m.m1)
#fg_4.add_to(m.m2)

# %%
#fg_both = folium.FeatureGroup(name = 'Circle_Markers').add_to(m)
fg1 = folium.FeatureGroup(name = '2016~2018_Circle_Markers').add_to(m.m1)
g5 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유입> B markers').add_to(m.m1)
g6 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유입> C markers').add_to(m.m1)
g7 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유입> D markers').add_to(m.m1)
g8 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유입> F markers').add_to(m.m1)
g9 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유출> B markers').add_to(m.m1)
g10 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유출> C markers').add_to(m.m1)
g11 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유출> D markers').add_to(m.m1)
g12 = folium.plugins.FeatureGroupSubGroup(fg1, name = '<유출> F markers').add_to(m.m1)

fg2 = folium.FeatureGroup(name = '2018~2021_Circle_Markers').add_to(m.m2)
h5 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유입> B markers').add_to(m.m2)
h6 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유입> C markers').add_to(m.m2)
h7 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유입> D markers').add_to(m.m2)
h8 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유입> F markers').add_to(m.m2)
h9 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유출> B markers').add_to(m.m2)
h10 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유출> C markers').add_to(m.m2)
h11 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유출> D markers').add_to(m.m2)
h12 = folium.plugins.FeatureGroupSubGroup(fg2, name = '<유출> F markers').add_to(m.m2)



folium.LayerControl(collapsed = True).add_to(m)

# %%
# B지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.4698955,127.0111568],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g5)

folium.CircleMarker(
    [37.5842516,126.7950705],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g5)

folium.CircleMarker(
    [37.5544386,127.1083746],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g5)

# C지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.5146526,126.9953166],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g6)

folium.CircleMarker(
    [37.5980835,126.8076522],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g6)

folium.CircleMarker(
    [37.541873,126.9004095],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g6)

# D지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.4874685,127.0991305],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.5255095,126.8331795],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.5153466,126.9300843],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.499739,127.110007],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

folium.CircleMarker(
    [37.611668,126.982551],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g7)

# F지점 증가율 상위(2016~2018 <유입>)
folium.CircleMarker(
    [37.446118, 126.923663],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g8)

# %%
# B지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.4698955,127.0111568],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g9)

folium.CircleMarker(
    [37.5842516,126.7950705],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g9)

folium.CircleMarker(
    [37.6186095,127.1023901],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g9)

# C지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.5146526,126.9953166],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g10)

folium.CircleMarker(
    [37.5337975,126.9349198],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g10)

folium.CircleMarker(
    [37.541873,126.9004095],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g10)

# D지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.611668,126.982551],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.606604,127.046677],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.5153466,126.9300843],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.5255095,126.8331795],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

folium.CircleMarker(
    [37.4874685,127.0991305],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g11)

# F지점 증가율 상위(2016~2018 <유출>)
folium.CircleMarker(
    [37.446118, 126.923663],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g12)

folium.CircleMarker(
    [37.6044901,127.0526307],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(g12)

folium.CircleMarker(
    [37.511198,126.967319],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popup = 'University of Seoul'
).add_to(g12)

# %%
# B지점 증가율 상위(2018~2021 <유입>)
folium.CircleMarker(
    [37.4634929,127.0375331],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h5)

folium.CircleMarker(
    [37.5722784,126.9011233],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h5)

folium.CircleMarker(
    [37.6941317,127.0509975],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h5)

# C지점 증가율 상위(2018~2021 <유입>)
folium.CircleMarker(
    [37.5146526,126.9953166],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h6)

folium.CircleMarker(
    [37.5370472,127.0327411],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h6)

# D지점 증가율 상위(2018~2021 <유입>)
folium.CircleMarker(
    [37.6327227,127.060932],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h7)

folium.CircleMarker(
    [37.5237506,126.9848424],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h7)

folium.CircleMarker(
    [37.5393132,126.8237634],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h7)

folium.CircleMarker(
    [37.4874685,127.0991305],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h7)

# F지점 증가율 상위(2018~2021 <유입>)
folium.CircleMarker(
    [37.446118, 126.923663],
    radius = 25,
    color = 'red',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h8)

# %%
# B지점 증가율 상위(2018~2021 <유출>)
folium.CircleMarker(
    [37.5491794,127.177156],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h9)

folium.CircleMarker(
    [37.5722784,126.9011233],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h9)

folium.CircleMarker(
    [37.4516714,126.8997134],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h9)

# C지점 증가율 상위(2018~2021 <유출>)
folium.CircleMarker(
    [37.5146526,126.9953166],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h10)


folium.CircleMarker(
    [37.5980835,126.8076522],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h10)

folium.CircleMarker(
    [37.544881,127.110604],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h10)

# D지점 증가율 상위(2018~2021 <유출>)
folium.CircleMarker(
    [37.5644094,126.9269758],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h11)

folium.CircleMarker(
    [37.4647718,127.1060713],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h11)

folium.CircleMarker(
    [37.59501,126.938436],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h11)

folium.CircleMarker(
    [37.4558229,126.794963],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h11)

# F지점 증가율 상위(2018~2021 <유출>)
folium.CircleMarker(
    [37.446118, 126.923663],
    radius = 20,
    color = 'blue',
    fill_color = '#ffffggg',
    popip = 'University of Seoul'
).add_to(h12)

# %%
m.save('./CSV/population/dualmap.html')
