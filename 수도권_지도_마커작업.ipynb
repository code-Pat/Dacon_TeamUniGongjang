# %%
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
import folium
from folium import plugins
from folium.features import CustomIcon
import json
import requests
import os
import webbrowser

# %%
seoul_map = folium.Map(location = [37.5502, 126.982],
                      zoom_start = 10.5,
                      tiles = 'cartodbpositron')
                      #tiles = 'openstreetmap')

# %%
fg = folium.FeatureGroup(name = 'markers')
seoul_map.add_child(fg)
g1 = folium.plugins.FeatureGroupSubGroup(fg, 'B_Points')
seoul_map.add_child(g1)
g2 = folium.plugins.FeatureGroupSubGroup(fg, 'C_Points')
seoul_map.add_child(g2)
g3 = folium.plugins.FeatureGroupSubGroup(fg, 'D_Points')
seoul_map.add_child(g3)
g4 = folium.plugins.FeatureGroupSubGroup(fg, 'F_Points')
seoul_map.add_child(g4)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_589ec71a8ae54fdb937121b535fecfaa%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//unpkg.com/leaflet.featuregroup.subgroup%401.0.2/dist/leaflet.featuregroup.subgroup.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_589ec71a8ae54fdb937121b535fecfaa%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_589ec71a8ae54fdb937121b535fecfaa%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_589ec71a8ae54fdb937121b535fecfaa%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20% ...

# %%
icon_number_b1 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 1,
    inner_icon_style = 'margin-top:0'
)
icon_number_b2 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 2,
    inner_icon_style = 'margin-top:0'
)
icon_number_b3 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 3,
    inner_icon_style = 'margin-top:0'
)
icon_number_b4 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_b5 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_b6 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_b7 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_b8 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_b9 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 9,
    inner_icon_style = 'margin-top:0'
)
icon_number_b10 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 10,
    inner_icon_style = 'margin-top:0'
)
icon_number_b11 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 11,
    inner_icon_style = 'margin-top:0'
)
icon_number_b12 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 12,
    inner_icon_style = 'margin-top:0'
)
icon_number_b13 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 13,
    inner_icon_style = 'margin-top:0'
)
icon_number_b14 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 14,
    inner_icon_style = 'margin-top:0'
)
icon_number_b15 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 15,
    inner_icon_style = 'margin-top:0'
)
icon_number_b16 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 16,
    inner_icon_style = 'margin-top:0'
)
icon_number_b17 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 17,
    inner_icon_style = 'margin-top:0'
)
icon_number_b18 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 18,
    inner_icon_style = 'margin-top:0'
)
icon_number_b19 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 19,
    inner_icon_style = 'margin-top:0'
)
icon_number_b20 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 20,
    inner_icon_style = 'margin-top:0'
)
icon_number_b21 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 21,
    inner_icon_style = 'margin-top:0'
)
icon_number_b22 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 22,
    inner_icon_style = 'margin-top:0'
)
icon_number_b23 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 23,
    inner_icon_style = 'margin-top:0'
)
icon_number_b24 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 24,
    inner_icon_style = 'margin-top:0'
)
icon_number_b25 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 25,
    inner_icon_style = 'margin-top:0'
)
icon_number_b26 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 26,
    inner_icon_style = 'margin-top:0'
)
icon_number_b27 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 27,
    inner_icon_style = 'margin-top:0'
)
icon_number_b28 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 28,
    inner_icon_style = 'margin-top:0'
)
icon_number_b29 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 29,
    inner_icon_style = 'margin-top:0'
)
icon_number_b30 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 30,
    inner_icon_style = 'margin-top:0'
)
icon_number_b31 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 31,
    inner_icon_style = 'margin-top:0'
)
icon_number_b32 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 32,
    inner_icon_style = 'margin-top:0'
)
icon_number_b33 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 33,
    inner_icon_style = 'margin-top:0'
)
icon_number_b34 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 34,
    inner_icon_style = 'margin-top:0'
)
icon_number_b35 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 35,
    inner_icon_style = 'margin-top:0'
)
icon_number_b36 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 36,
    inner_icon_style = 'margin-top:0'
)
icon_number_b37 = plugins.BeautifyIcon(
    border_color = '#FF0000', 
    text_color = '#FF0000',
    number = 37,
    inner_icon_style = 'margin-top:0'
)


tooltip = "Click"

# %%
folium.Marker(
    location = [37.6899062,127.0428593], 
    popup = "<b>B-1 도봉로</b>",
    tooltip = tooltip,
    icon = icon_number_b1
    ).add_to(g1)

folium.Marker(
    location = [37.6941317,127.0509975],
    popup = "<b>B-2 동일로</b>", 
    tooltip = tooltip,
    icon = icon_number_b2
    ).add_to(g1)

folium.Marker(
    location = [37.5544386,127.1083746],
    popup = "<b>B-3 아차산로</b>", 
    tooltip = tooltip,
    icon = icon_number_b3
    ).add_to(g1)

folium.Marker(
    location = [37.5947282,127.1102168],
    popup = "<b>B-4 망우로</b>", 
    tooltip = tooltip,
    icon = icon_number_b4
).add_to(g1)

folium.Marker(
    location = [37.6186095,127.1023901],
    popup = "<b>B-5 경춘북로</b>", 
    tooltip = tooltip,
    icon = icon_number_b5
).add_to(g1)

folium.Marker(
    location = [37.6186082,127.0871067],
    popup = "<b>B-6 화랑로</b>",
    tooltip = tooltip,
    icon = icon_number_b6
).add_to(g1)

folium.Marker(
    location = [37.6111681,127.1124202],
    popup = "<b>B-7 북부간선</b>",
    tooltip = tooltip,
    icon = icon_number_b7
).add_to(g1)

folium.Marker(
    location = [37.5126834,127.1500208],
    popup = "<b>B-8 서하남로</b>",
    tooltip = tooltip,
    icon = icon_number_b8
).add_to(g1)

folium.Marker(
    location = [37.5491794,127.177156],
    popup = "<b>B-9 천호대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b9
).add_to(g1)

folium.Marker(
    location = [37.5730652,127.1634344], 
    popup = "<b>B-10 올림픽대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b10
).add_to(g1)

folium.Marker(
    location = [37.4634929,127.0375331],
    popup = "<b>B-11 경부고속</b>", 
    tooltip = tooltip,
    icon = icon_number_b11
).add_to(g1)

folium.Marker(
    location = [37.4701094,127.1217181],
    popup = "<b>B-12 송파대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b12
).add_to(g1)

folium.Marker(
    location = [37.4647718,127.106082],
    popup = "<b>B-13 밤고개로</b>",
    tooltip = tooltip,
    icon = icon_number_b13
).add_to(g1)

folium.Marker(
    location = [37.3718672,127.0997269],
    popup = "<b>B-14 분당수서</b>", 
    tooltip = tooltip,
    icon = icon_number_b14
).add_to(g1)

folium.Marker(
    location = [37.464237,126.9869137],
    popup = "<b>B-15 과천대로</b>",
    tooltip = tooltip,
    icon = icon_number_b15
).add_to(g1)

folium.Marker(
    location = [37.4634929,127.0375331],
    popup = "<b>B-16 양재대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b16
).add_to(g1)

folium.Marker(
    location = [37.4698955,127.0111568],
    popup = "<b>B-17 반포대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b17
).add_to(g1)

folium.Marker(
    location = [37.435161,126.9000497], 
    popup = "<b>B-18 시흥대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b18
).add_to(g1)

folium.Marker(
    location = [37.4369705,126.8144138],
    popup = "<b>B-19 금오로</b>", 
    tooltip = tooltip,
    icon = icon_number_b19
).add_to(g1)

folium.Marker(
    location = [37.4468478,126.8315392], 
    popup = "<b>B-20 오리로</b>",
    tooltip = tooltip,
    icon = icon_number_b20
).add_to(g1)

folium.Marker(
    location = [37.4856259,126.8543174], 
    popup = "<b>B-21 개봉로</b>",  
    tooltip = tooltip,
    icon = icon_number_b21
).add_to(g1)

folium.Marker(
    location = [37.4849595,126.8688716],
    popup = "<b>B-22 광명대교</b>",
    tooltip = tooltip,
    icon = icon_number_b22
).add_to(g1)

folium.Marker(
    location = [37.4811723,126.8598571],
    popup = "<b>B-23 철산교</b>",
    tooltip = tooltip,
    icon = icon_number_b23
).add_to(g1)

folium.Marker(
    location = [37.4659066,126.8853011], 
    popup = "<b>B-24 금천교</b>", 
    tooltip = tooltip,
    icon = icon_number_b24
).add_to(g1)

folium.Marker(
    location = [37.4516714,126.8997134], 
    popup = "<b>B-25 금하로</b>",
    tooltip = tooltip,
    icon = icon_number_b25
).add_to(g1)

folium.Marker(
    location = [37.5192016,126.754606], 
    popup = "<b>B-26 오정로</b>", 
    tooltip = tooltip,
    icon = icon_number_b26
).add_to(g1)

folium.Marker(
    location = [37.5393132,126.8237634],
    popup = "<b>B-27 화곡로</b>",
    tooltip = tooltip,
    icon = icon_number_b27
).add_to(g1)

folium.Marker(
    location = [37.5255095,126.8331795], 
    popup = "<b>B-28 경인고속국도</b>", 
    tooltip = tooltip,
    icon = icon_number_b28
).add_to(g1)

folium.Marker(
    location = [37.4879732,126.8217219], 
    popup = "<b>B-29 경인로</b>", 
    tooltip = tooltip,
    icon = icon_number_b29
).add_to(g1)

folium.Marker(
    location = [37.506039,126.820681], 
    popup = "<b>B-30 신정로</b>",
    tooltip = tooltip,
    icon = icon_number_b30
).add_to(g1)

folium.Marker(
    location = [37.491799,126.7487928], 
    popup = "<b>B-31 김포대로</b>", 
    tooltip = tooltip,
    icon = icon_number_b31
).add_to(g1)

folium.Marker(
    location = [37.5842516,126.7950705], 
    popup = "<b>B-32 올림픽대로</b>",
    tooltip = tooltip,
    icon = icon_number_b32
).add_to(g1)

folium.Marker(
    location = [37.6218508,126.906438], 
    popup = "<b>B-33 통일로</b>",  
    tooltip = tooltip,
    icon = icon_number_b33
).add_to(g1)

folium.Marker(
    location = [37.6331794,126.8432692], 
    popup = "<b>B-34 서오릉로</b>",
    tooltip = tooltip,
    icon = icon_number_b34
).add_to(g1)

folium.Marker(
    location = [37.5722784,126.9011233],
    popup = "<b>B-35 수색로</b>",
    tooltip = tooltip,
    icon = icon_number_b35
).add_to(g1)

folium.Marker(
    location = [37.569246,126.8687315], 
    popup = "<b>B-36 강변북로(난지공원)</b>", 
    tooltip = tooltip,
    icon = icon_number_b36
).add_to(g1)

folium.Marker(
    location = [37.5756393,127.1227722], 
    popup = "<b>B-37 강변북로(구리시계)</b>",  
    tooltip = tooltip,
    icon = icon_number_b37
).add_to(g1)

# %%
icon_number_c1 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 1,
    inner_icon_style = 'margin-top:0'
)
icon_number_c3 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 3,
    inner_icon_style = 'margin-top:0'
)
icon_number_c4 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_c5 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_c6 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_c7 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_c8 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_c9 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 9,
    inner_icon_style = 'margin-top:0'
)
icon_number_c10 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 10,
    inner_icon_style = 'margin-top:0'
)
icon_number_c11 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 11,
    inner_icon_style = 'margin-top:0'
)
icon_number_c12 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 12,
    inner_icon_style = 'margin-top:0'
)
icon_number_c13 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 13,
    inner_icon_style = 'margin-top:0'
)
icon_number_c14 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 14,
    inner_icon_style = 'margin-top:0'
)
icon_number_c15 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 15,
    inner_icon_style = 'margin-top:0'
)
icon_number_c16 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 16,
    inner_icon_style = 'margin-top:0'
)
icon_number_c17 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 17,
    inner_icon_style = 'margin-top:0'
)
icon_number_c18 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 18,
    inner_icon_style = 'margin-top:0'
)
icon_number_c19 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 19,
    inner_icon_style = 'margin-top:0'
)
icon_number_c20 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 20,
    inner_icon_style = 'margin-top:0'
)
icon_number_c21 = plugins.BeautifyIcon(
    border_color = '#8041D9', 
    text_color = '#8041D9',
    number = 21,
    inner_icon_style = 'margin-top:0'
)

# %%
folium.Marker(
    location = [37.5980835,126.8076522], 
    popup = "<b>C-01 행주대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c1
).add_to(g2)

folium.Marker(
    location = [37.5692971,126.8588536], 
    popup = "<b>C-03 가양대로</b>", 
    tooltip = tooltip,
    icon = icon_number_c3
).add_to(g2)

folium.Marker(
    location = [37.5528405,126.889451], 
    popup = "<b>C-04 성산대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c4
).add_to(g2)

folium.Marker(
    location = [37.541873,126.9004095], 
    popup = "<b>C-05 양화대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c5
).add_to(g2)

folium.Marker(
    location = [37.5370177,126.9228495], 
    popup = "<b>C-06 서강대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c6
).add_to(g2)

folium.Marker(
    location = [37.5337975,126.9349198], 
    popup = "<b>C-07 마포대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c7
).add_to(g2)

folium.Marker(
    location = [37.527039,126.94353], 
    popup = "<b>C-08 원효대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c8
).add_to(g2)

folium.Marker(
    location = [37.5175177,126.9566667], 
    popup = "<b>C-09 한강대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c9
).add_to(g2)

folium.Marker(
    location = [37.5086737,126.9792945], 
    popup = "<b>C-10 동작대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c10
).add_to(g2)

folium.Marker(
    location = [37.5141186,126.9959445], 
    popup = "<b>C-11 반포대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c11
).add_to(g2)

folium.Marker(
    location = [37.5146526,126.9953166], 
    popup = "<b>C-12 잠수교</b>", 
    tooltip = tooltip,
    icon = icon_number_c12
).add_to(g2)

folium.Marker(
    location = [37.5258295,127.0133125], 
    popup = "<b>C-13 한남대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c13
).add_to(g2)

folium.Marker(
    location = [37.536178,127.018856], 
    popup = "<b>C-14 동호대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c14
).add_to(g2)

folium.Marker(
    location = [37.5370472,127.0327411], 
    popup = "<b>C-15 성수대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c15
).add_to(g2)

folium.Marker(
    location = [37.530207,127.055019], 
    popup = "<b>C-16 영동대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c16
).add_to(g2)

folium.Marker(
    location = [37.526569,127.062268], 
    popup = "<b>C-17 청담대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c17
).add_to(g2)

folium.Marker(
    location = [37.5243505,127.0894026], 
    popup = "<b>C-18 잠실대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c18
).add_to(g2)

folium.Marker(
    location = [37.5339577,127.1016808], 
    popup = "<b>C-19 올림픽대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c19
).add_to(g2)

folium.Marker(
    location = [37.542929,127.1095965], 
    popup = "<b>C-20 천호대교</b>", 
    tooltip = tooltip,
    icon = icon_number_c20
).add_to(g2)

folium.Marker(
    location = [37.544881,127.110604], 
    popup = "<b>C-21 광진교</b>", 
    tooltip = tooltip,
    icon = icon_number_c21
).add_to(g2)

# %%
icon_number_d1 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 1 ,
    inner_icon_style = 'margin-top:0'
)
icon_number_d2 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 2,
    inner_icon_style = 'margin-top:0'
)
icon_number_d3 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 3,
    inner_icon_style = 'margin-top:0'
)
icon_number_d4 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_d5 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_d6 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_d7 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_d8 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_d9 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 9,
    inner_icon_style = 'margin-top:0'
)
icon_number_d10 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 10,
    inner_icon_style = 'margin-top:0'
)
icon_number_d11 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 11,
    inner_icon_style = 'margin-top:0'
)
icon_number_d12 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 12,
    inner_icon_style = 'margin-top:0'
)
icon_number_d13 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 13,
    inner_icon_style = 'margin-top:0'
)
icon_number_d14 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 14,
    inner_icon_style = 'margin-top:0'
)
icon_number_d15 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 15,
    inner_icon_style = 'margin-top:0'
)
icon_number_d16 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 16,
    inner_icon_style = 'margin-top:0'
)
icon_number_d17 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 17,
    inner_icon_style = 'margin-top:0'
)
icon_number_d18 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 18,
    inner_icon_style = 'margin-top:0'
)
icon_number_d19 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 19,
    inner_icon_style = 'margin-top:0'
)
icon_number_d20 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 20,
    inner_icon_style = 'margin-top:0'
)
icon_number_d21 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 21,
    inner_icon_style = 'margin-top:0'
)
icon_number_d22 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 22,
    inner_icon_style = 'margin-top:0'
)
icon_number_d23 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 23,
    inner_icon_style = 'margin-top:0'
)
icon_number_d24 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 24,
    inner_icon_style = 'margin-top:0'
)
icon_number_d25 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 25,
    inner_icon_style = 'margin-top:0'
)
icon_number_d26 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 26,
    inner_icon_style = 'margin-top:0'
)
icon_number_d27 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 27,
    inner_icon_style = 'margin-top:0'
)
icon_number_d28 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 28,
    inner_icon_style = 'margin-top:0'
)
icon_number_d29 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 29,
    inner_icon_style = 'margin-top:0'
)
icon_number_d30 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 30,
    inner_icon_style = 'margin-top:0'
)
icon_number_d31 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 31,
    inner_icon_style = 'margin-top:0'
)
icon_number_d32 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 32,
    inner_icon_style = 'margin-top:0'
)
icon_number_d33 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 33,
    inner_icon_style = 'margin-top:0'
)
icon_number_d34 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 34,
    inner_icon_style = 'margin-top:0'
)
icon_number_d35 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 35,
    inner_icon_style = 'margin-top:0'
)
icon_number_d36 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 36,
    inner_icon_style = 'margin-top:0'
)
icon_number_d37 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 37,
    inner_icon_style = 'margin-top:0'
)
icon_number_d38 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 38,
    inner_icon_style = 'margin-top:0'
)
icon_number_d39 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 39,
    inner_icon_style = 'margin-top:0'
)
icon_number_d40 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 40,
    inner_icon_style = 'margin-top:0'
)
icon_number_d41 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 41,
    inner_icon_style = 'margin-top:0'
)
icon_number_d42 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 42,
    inner_icon_style = 'margin-top:0'
)
icon_number_d43 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 43,
    inner_icon_style = 'margin-top:0'
)
icon_number_d44 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 44,
    inner_icon_style = 'margin-top:0'
)
icon_number_d45 = plugins.BeautifyIcon(
    border_color = '#47C83E', 
    text_color = '#47C83E',
    number = 45,
    inner_icon_style = 'margin-top:0'
)

# %%
folium.Marker(
    location = [37.6094457,126.9490825], 
    popup = "<b>D-01 진흥로</b>", 
    tooltip = tooltip,
    icon = icon_number_d1
).add_to(g3)

folium.Marker(
    location = [37.611668,126.982551], 
    popup = "<b>D-02 평창문화로</b>", 
    tooltip = tooltip,
    icon = icon_number_d2
).add_to(g3)

folium.Marker(
    location = [37.5504819,127.0119391], 
    popup = "<b>D-03 동호로</b>", 
    tooltip = tooltip,
    icon = icon_number_d3
).add_to(g3)

folium.Marker(
    location = [37.529361,127.00679], 
    popup = "<b>D-04 서빙고로</b>", 
    tooltip = tooltip,
    icon = icon_number_d4
).add_to(g3)

folium.Marker(
    location = [37.5610318,127.0714966], 
    popup = "<b>D-05 천호대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d5
).add_to(g3)

folium.Marker(
    location = [37.5455896,127.0291416], 
    popup = "<b>D-06 뚝섬로</b>", 
    tooltip = tooltip,
    icon = icon_number_d6
).add_to(g3)

folium.Marker(
    location = [37.5559148,127.0707977], 
    popup = "<b>D-07 동일로</b>", 
    tooltip = tooltip,
    icon = icon_number_d7
).add_to(g3)

folium.Marker(
    location = [37.606604,127.046677], 
    popup = "<b>D-08 화랑로</b>", 
    tooltip = tooltip,
    icon = icon_number_d8
).add_to(g3)

folium.Marker(
    location = [37.6015956,127.0189499], 
    popup = "<b>D-09 동소문로</b>", 
    tooltip = tooltip,
    icon = icon_number_d9
).add_to(g3)

folium.Marker(
    location = [37.6015747,126.9533875], 
    popup = "<b>D-10 화랑로</b>", 
    tooltip = tooltip,
    icon = icon_number_d10
).add_to(g3)

folium.Marker(
    location = [37.6435347,127.0240008], 
    popup = "<b>D-11 도봉로</b>", 
    tooltip = tooltip,
    icon = icon_number_d11
).add_to(g3)

folium.Marker(
    location = [37.6327227,127.060932], 
    popup = "<b>D-12 동부간선도로</b>", 
    tooltip = tooltip,
    icon = icon_number_d12
).add_to(g3)

folium.Marker(
    location = [37.655341,127.0596715], 
    popup = "<b>D-13 동일로</b>", 
    tooltip = tooltip,
    icon = icon_number_d13
).add_to(g3)

folium.Marker(
    location = [37.5779636,126.8982265], 
    popup = "<b>D-14 증산로</b>", 
    tooltip = tooltip,
    icon = icon_number_d14
).add_to(g3)

folium.Marker(
    location = [37.59501,126.938436], 
    popup = "<b>D-15 통일로</b>", 
    tooltip = tooltip,
    icon = icon_number_d15
).add_to(g3)

folium.Marker(
    location = [37.5644231,126.9268637], 
    popup = "<b>D-16 성산로</b>", 
    tooltip = tooltip,
    icon = icon_number_d16
).add_to(g3)

folium.Marker(
    location = [37.5644094,126.9269758], 
    popup = "<b>D-17 연희로</b>", 
    tooltip = tooltip,
    icon = icon_number_d17
).add_to(g3)

folium.Marker(
    location = [37.5393132,126.8237634], 
    popup = "<b>D-18 남부순환로</b>", 
    tooltip = tooltip,
    icon = icon_number_d18
).add_to(g3)

folium.Marker(
    location = [37.5255095,126.8331795], 
    popup = "<b>D-19 남부순환로</b>", 
    tooltip = tooltip,
    icon = icon_number_d19
).add_to(g3)

folium.Marker(
    location = [37.5360361,126.8418728], 
    popup = "<b>D-20 강서로</b>", 
    tooltip = tooltip,
    icon = icon_number_d20
).add_to(g3)

folium.Marker(
    location = [37.558683,126.835401], 
    popup = "<b>D-21 공항대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d21
).add_to(g3)

folium.Marker(
    location = [37.4980687,126.8465123], 
    popup = "<b>D-22 경인로</b>", 
    tooltip = tooltip,
    icon = icon_number_d22
).add_to(g3)

folium.Marker(
    location = [37.5069016,126.8831751], 
    popup = "<b>D-23 경인로</b>", 
    tooltip = tooltip,
    icon = icon_number_d23
).add_to(g3)

folium.Marker(
    location = [37.4558229,126.794963], 
    popup = "<b>D-24 시흥대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d24
).add_to(g3)

folium.Marker(
    location = [37.524553,126.872856], 
    popup = "<b>D-25 영등포로</b>", 
    tooltip = tooltip,
    icon = icon_number_d25
).add_to(g3)

folium.Marker(
    location = [37.485215,126.8994], 
    popup = "<b>D-26 시흥대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d26
).add_to(g3)

folium.Marker(
    location = [37.5262608,126.9100609], 
    popup = "<b>D-27 국회대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d27
).add_to(g3)

folium.Marker(
    location = [37.52065,126.913755], 
    popup = "<b>D-28 경인로</b>", 
    tooltip = tooltip,
    icon = icon_number_d28
).add_to(g3)

folium.Marker(
    location = [37.4926529,126.9127281], 
    popup = "<b>D-29 여의대방로</b>", 
    tooltip = tooltip,
    icon = icon_number_d29
).add_to(g3)

folium.Marker(
    location = [37.5086836,126.949916], 
    popup = "<b>D-30 양녕로</b>", 
    tooltip = tooltip,
    icon = icon_number_d30
).add_to(g3)

folium.Marker(
    location = [37.4869898,126.9798559], 
    popup = "<b>D-31 동작대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d31
).add_to(g3)

folium.Marker(
    location = [37.4784043,126.9181706], 
    popup = "<b>D-32 문성로</b>", 
    tooltip = tooltip,
    icon = icon_number_d32
).add_to(g3)

folium.Marker(
    location = [37.477117,126.961224], 
    popup = "<b>D-33 남부순환로</b>", 
    tooltip = tooltip,
    icon = icon_number_d33
).add_to(g3)

folium.Marker(
    location = [37.4789459,127.0092195], 
    popup = "<b>D-34 남부순환로</b>", 
    tooltip = tooltip,
    icon = icon_number_d34
).add_to(g3)

folium.Marker(
    location = [37.4979083,127.0200692], 
    popup = "<b>D-35 강남대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d35
).add_to(g3)

folium.Marker(
    location = [37.504522,127.0017981], 
    popup = "<b>D-36 사평대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d36
).add_to(g3)

folium.Marker(
    location = [37.49184,127.005494], 
    popup = "<b>D-37 반포대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d37
).add_to(g3)

folium.Marker(
    location = [37.490712,127.0462986], 
    popup = "<b>D-38 언주로</b>", 
    tooltip = tooltip,
    icon = icon_number_d38
).add_to(g3)

folium.Marker(
    location = [37.4874685,127.0991305], 
    popup = "<b>D-39 남부순환로</b>", 
    tooltip = tooltip,
    icon = icon_number_d39
).add_to(g3)

folium.Marker(
    location = [37.4647718,127.1060713], 
    popup = "<b>D-40 헌릉로</b>", 
    tooltip = tooltip,
    icon = icon_number_d40
).add_to(g3)

folium.Marker(
    location = [37.5153466,126.9300843], 
    popup = "<b>D-41 노들로</b>", 
    tooltip = tooltip,
    icon = icon_number_d41
).add_to(g3)

folium.Marker(
    location = [37.5051365,127.046395], 
    popup = "<b>D-42 테헤란로</b>", 
    tooltip = tooltip,
    icon = icon_number_d42
).add_to(g3)

folium.Marker(
    location = [37.5237561,127.0112143], 
    popup = "<b>D-43 강남대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d43
).add_to(g3)

folium.Marker(
    location = [37.5237506,126.9848424], 
    popup = "<b>D-44 백제고분로</b>", 
    tooltip = tooltip,
    icon = icon_number_d44
).add_to(g3)

folium.Marker(
    location = [37.499739,127.110007], 
    popup = "<b>D-45 송파대로</b>", 
    tooltip = tooltip,
    icon = icon_number_d45
).add_to(g3)

# %%
icon_number_f1 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 1,
    inner_icon_style = 'margin-top:0'
)
icon_number_f2 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 2,
    inner_icon_style = 'margin-top:0'
)
icon_number_f3_1 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 3.1,
    inner_icon_style = 'margin-top:0'
)
icon_number_f3_2 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 3.2,
    inner_icon_style = 'margin-top:0'
)
icon_number_f4 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 4,
    inner_icon_style = 'margin-top:0'
)
icon_number_f5 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 5,
    inner_icon_style = 'margin-top:0'
)
icon_number_f6 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 6,
    inner_icon_style = 'margin-top:0'
)
icon_number_f7 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 7,
    inner_icon_style = 'margin-top:0'
)
icon_number_f8 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 8,
    inner_icon_style = 'margin-top:0'
)
icon_number_f9 = plugins.BeautifyIcon(
    border_color = '#5CD1E5', 
    text_color = '#5CD1E5',
    number = 9,
    inner_icon_style = 'margin-top:0'
)

# %%
folium.Marker(
    location = [37.5051387,126.9647395], 
    popup = "<b>F-01 올림픽대로</b>", 
    tooltip = tooltip,
    icon = icon_number_f1
).add_to(g4)

folium.Marker(
    location = [37.511198,126.967319], 
    popup = "<b>F-02 강변북로</b>", 
    tooltip = tooltip,
    icon = icon_number_f2
).add_to(g4)

folium.Marker(
    location = [37.5947411,126.9541272], 
    popup = "<b>F-03 내부순환로(유출)</b>", 
    tooltip = tooltip,
    icon = icon_number_f3_1
).add_to(g4)

folium.Marker(
    location = [37.6076494,126.9928635], 
    popup = "<b>F-03 내부순환로(유입)</b>", 
    tooltip = tooltip,
    icon = icon_number_f3_2
).add_to(g4)

folium.Marker(
    location = [37.6044901,127.0526307], 
    popup = "<b>F-04 북부간선도로</b>", 
    tooltip = tooltip,
    icon = icon_number_f4
).add_to(g4)

folium.Marker(
    location = [37.574336, 127.077292], 
    popup = "<b>F-05 동부간선도로</b>", 
    tooltip = tooltip,
    icon = icon_number_f5
).add_to(g4)

folium.Marker(
    location = [37.493237, 127.022355], 
    popup = "<b>F-06 경부고속도로</b>", 
    tooltip = tooltip,
    icon = icon_number_f6
).add_to(g4)

folium.Marker(
    location = [37.497939, 127.085948], 
    popup = "<b>F-07 분당수서로</b>",
    tooltip = tooltip,
    icon = icon_number_f7
).add_to(g4)

folium.Marker(
    location = [37.446118, 126.923663], 
    popup = "<b>F-08 강남순환로</b>", 
    tooltip = tooltip,
    icon = icon_number_f8
).add_to(g4)

folium.Marker(
    location = [37.521245, 126.881726], 
    popup = "<b>F-09 서부간선도로</b>", 
    tooltip = tooltip,
    icon = icon_number_f9
).add_to(g4)

# %%
folium.LayerControl(callapsed = True).add_to(seoul_map)

# %%
seoul_map.save('./CSV/population/markers_test_map.html')
